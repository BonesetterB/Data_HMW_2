# %% [markdown]
# <a href="https://colab.research.google.com/github/BonesetterB/Data_HMW_2/blob/main/Hw2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount("/drive",force_remount=True)
# Out:
# Mounted at /drive

# %%
table=pd.read_csv("/drive/My Drive/bestsellers with categories.csv")
print(table.head())
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
print(table.shape)
# Out:
# (550, 7)

# %%
print(table)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Відповідь: Про скільки книг зберігає дані датасет?
#
# ---
# В статті було написано що тут зберігається 50 книг, але вони чомусь півторяються, тож датасет зберігає понад 549 книг з повторами

# %%
table.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
print(table)
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
missing_percentage = (table.isnull().sum() / len(table)) * 100

print(missing_percentage)
# Out:
# name           0.0
# author         0.0
# user_rating    0.0
# reviews        0.0
# price          0.0
# year           0.0
# genre          0.0
# dtype: float64

# %% [markdown]
# Відповідь: Чи є в якихось змінних пропуски? (Так / ні)
#
# ---
# Ні немає

# %%
unique_genres = table['genre'].unique()
print(unique_genres)
# Out:
# ['Non Fiction' 'Fiction']

# %% [markdown]
# Відповідь: Які є унікальні жанри?
# Є Нехудожня література та Художня література

# %%
prices = table['price']

sns.histplot(prices, bins=20, kde=True)
plt.title('Розподіл цін')
plt.xlabel('Ціна')
plt.ylabel('Частота')
plt.show()

# %%
print(prices.min())
print(prices.max())
print(prices.mean())
print(prices.median())
# Out:
# 0
# 105
# 13.1
# 11.0

# %% [markdown]
# Відповідь: Максимальна ціна?
# Відповідь: Мінімальна ціна?
# Відповідь: Середня ціна?
# Відповідь: Медіанна ціна?
# Максимальна ціна 105
# Мінімальна ціна 0
# Середня ціна 13,1
# Медіана 11

# %%
x=table['user_rating'].max()
print(x)
# Out:
# 4.9

# %%
books_with_max_rating = table[table['user_rating'] == x]
count_books_with_max_rating = len(books_with_max_rating)
print(count_books_with_max_rating)
# Out:
# 52

# %% [markdown]
# Відповідь: Який рейтинг у датасеті найвищий? Відповідь: 4.9
# Відповідь: Скільки книг мають такий рейтинг? Відповідь:52

# %%
book=table[table['reviews'] == table['reviews'].max()]
print(book)
# Out:
#                         name       author  user_rating  reviews  price  year  \
# 534  Where the Crawdads Sing  Delia Owens          4.8    87841     15  2019
#
#        genre
# 534  Fiction

# %% [markdown]
# Відповідь: Яка книга має найбільше відгуків? Відповідь:Where the Crawdads Sing

# %%
book=table[table['price'] == table['price'].max()]
print(book['name'])
# Out:
# 69    Diagnostic and Statistical Manual of Mental Di...
# 70    Diagnostic and Statistical Manual of Mental Di...
# Name: name, dtype: object

# %% [markdown]
# Відповідь: З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)? Відповідь: Diagnostic and Statistical Manual of Mental Di...

# %%
books = table[(table['genre'] == 'Fiction') & (table['year'] == 2010)]

# Підраховуємо кількість книг, які задовольняють цю умову
count_books = len(books)
print(count_books)
# Out:
# 20

# %% [markdown]
# Відповідь: Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)? Відповідь:  20

# %%
books = table[(table['user_rating'] == 4.9) & (table['year'] == 2010|2011)]


count_books = len(books)
print(count_books)
# Out:
# 1

# %% [markdown]
# Відповідь: Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)? Відповідь: 1

# %%
books = table[(table['year'] == 2015) & (table['price'] < 8)]

books_sort = books.sort_values(by='price')

print(books_sort)
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# 224                                   Love You Forever       Robert Munsch
# 55   Creative Haven Owls Coloring Book (Adult Color...     Marjorie Sarnat
# 17      Adult Coloring Book: Stress Relieving Patterns  Blue Star Coloring
# 376  The Four Agreements: A Practical Guide to Pers...     Don Miguel Ruiz
# 16   Adult Coloring Book: Stress Relieving Animal D...  Blue Star Coloring
# 253              Old School (Diary of a Wimpy Kid #10)         Jeff Kinney
#
#      user_rating  reviews  price  year        genre
# 507          4.8    26234      0  2015      Fiction
# 210          4.6     6990      4  2015  Non Fiction
# 206          4.5     3673      4  2015  Non Fiction
# 111          4.7    17323      4  2015  Non Fiction
# 123          4.8    14038      4  2015      Fiction
# 54           4.8     4022      4  2015  Non Fiction
# 63           4.8    10922      5  2015      Fiction
# 89           4.6     2134      5  2015  Non Fiction
# 478          4.9    19546      5  2015      Fiction
# 201          4.6     5235      5  2015  Non Fiction
# 28           4.6     5360      5  2015  Non Fiction
# 224          4.8    18613      5  2015      Fiction
# 55           4.8     3871      5  2015  Non Fiction
# 17           4.4     2951      6  2015  Non Fiction
# 376          4.7    23308      6  2015  Non Fiction
# 16           4.6     2925      6  2015  Non Fiction
# 253          4.8     6169      7  2015      Fiction

# %% [markdown]
# Відповідь: Яка книга остання у відсортованому списку? Відповідь:  Old School (Diary of a Wimpy Kid #10)         Jeff Kinney

# %%
max_min = table.groupby('genre').agg({'price': ['max', 'min']})
print(max_min)
# Out:
#             price
#               max min
# genre
# Fiction        82   0
# Non Fiction   105   0

# %% [markdown]
# Відповідь: Максимальна ціна для жанру Fiction: Відповідь 82
#
# Відповідь: Мінімальна ціна для жанру Fiction: Відповідь 0
#
# Відповідь: Максимальна ціна для жанру Non Fiction: Відповідь 105
#
# Відповідь: Мінімальна ціна для жанру Non Fiction: Відповідь: 0

# %%
authors = table.groupby('author').agg({'name': 'count'})
print(authors)
print(authors[authors['name']==12])
print(authors.max())
# Out:
#                             name
# author
# Abraham Verghese               2
# Adam Gasiewski                 1
# Adam Mansbach                  1
# Adir Levy                      1
# Admiral William H. McRaven     1
# ...                          ...
# Walter Isaacson                3
# William Davis                  2
# William P. Young               2
# Wizards RPG Team               3
# Zhi Gang Sha                   2
#
# [248 rows x 1 columns]
#              name
# author
# Jeff Kinney    12
# name    12
# dtype: int64

# %% [markdown]
# Відповідь: Якої розмірності вийшла таблиця? Відповідь: [248 rows x 1 columns]
#
# Відповідь: Який автор має найбільше книг? Відповідь:Jeff Kinney
#
# Відповідь: Скільки книг цього автора? Відповідь: 12

# %%
authors_avg = table.groupby('author').agg({'user_rating': 'mean'})
print(authors_avg[authors_avg['user_rating']==authors_avg['user_rating'].min()])
# Out:
#              user_rating
# author
# Donna Tartt          3.9

# %% [markdown]
# Відповідь: У якого автора середній рейтинг мінімальний? Відповідь:Donna Tartt
#
# Відповідь: Який у цього автора середній рейтинг? Відповідь: 3.9

# %%
employees = pd.concat([authors, authors_avg], axis=1)

print(employees)
# Out:
#                             name  user_rating
# author
# Abraham Verghese               2     4.600000
# Adam Gasiewski                 1     4.400000
# Adam Mansbach                  1     4.800000
# Adir Levy                      1     4.800000
# Admiral William H. McRaven     1     4.700000
# ...                          ...          ...
# Walter Isaacson                3     4.566667
# William Davis                  2     4.400000
# William P. Young               2     4.600000
# Wizards RPG Team               3     4.800000
# Zhi Gang Sha                   2     4.600000
#
# [248 rows x 2 columns]

# %%
sorted_employees = employees.sort_values(by=['name', 'user_rating'], ascending=[True, True])

print(sorted_employees)
# Out:
#                                     name  user_rating
# author
# Muriel Barbery                         1     4.000000
# Chris Cleave                           1     4.100000
# Ian K. Smith M.D.                      1     4.100000
# Pierre Dukan                           1     4.100000
# Elizabeth Strout                       1     4.200000
# ...                                  ...          ...
# American Psychological Association    10     4.500000
# Suzanne Collins                       11     4.663636
# Gary Chapman                          11     4.736364
# Rick Riordan                          11     4.772727
# Jeff Kinney                           12     4.800000
#
# [248 rows x 2 columns]

# %% [markdown]
# Відповідь: Який автор перший у списку?
# Muriel Barbery

# %%
# %matplotlib inline

# %%
authors=authors.sort_values(by=['name'],ascending=False)
plt.plot(authors.head(10), label='count', color='green')
plt.xlabel('Автори', fontsize='medium', color='green')
plt.ylabel('Кількість', fontsize='medium', color='green')
plt.title('Кількість книг у кожного автора', fontsize=15)
plt.xticks( rotation=90)
plt.show()

# %%
authors_avg_rewie = table.groupby('author').agg({'reviews': 'mean'})
employees2 = pd.concat([employees, authors_avg_rewie], axis=1)
authors_2=employees2.sort_values(by=['name'],ascending=False)
plot=sns.scatterplot(x='name', y='user_rating', hue='author',  data=authors_2.head(10))
plot.figure.set_size_inches(20, 6)

plt.show()

# %%
plot2=sns.residplot(x="reviews", y="user_rating", data=authors_2)
plot2.figure.set_size_inches(10, 6)

plt.show()
